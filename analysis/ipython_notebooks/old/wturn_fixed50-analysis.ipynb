# %% [markdown]
# This notebook looks at the fits for the run where we fixed $\lambda_{turn}=50$ $\mu$m. All of the sources fit in this way only had 1 undetected point, usually the SPIRE PLW band.

# %%
#Import modules and set plotting to be inside the notebook
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from glob import glob
import pandas as pd
# %matplotlib inline
sns.set()

# %%
#Make sure the path to the modeling modules is in the PythonPath
import sys
sys.path.append('/ricci9nb/tshimizu/Github/bat-agn-sed-fitting/')

# %%
# Get all of the pickle files in the directory
pickle_files = glob('./pickles/*.pickle')
pickle_files
# Out:
# ['./pickles/NGC3516_casey_bayes_wturn_fixed50.pickle',
#  './pickles/MCG-07-03-007_casey_bayes_wturn_fixed50.pickle',
#  './pickles/2MASXJ20005575-1810274_casey_bayes_wturn_fixed50.pickle',
#  './pickles/CGCG420-015_casey_bayes_wturn_fixed50.pickle',
#  './pickles/MCG-03-04-072_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk885_casey_bayes_wturn_fixed50.pickle',
#  './pickles/CGCG122-055_casey_bayes_wturn_fixed50.pickle',
#  './pickles/2MASXJ12335145-2103448_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk279_casey_bayes_wturn_fixed50.pickle',
#  './pickles/CGCG493-002_casey_bayes_wturn_fixed50.pickle',
#  './pickles/KAZ320_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk653_casey_bayes_wturn_fixed50.pickle',
#  './pickles/IC4329A_casey_bayes_wturn_fixed50.pickle',
#  './pickles/NGC235A_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO506-G027_casey_bayes_wturn_fixed50.pickle',
#  './pickles/MCG-01-40-001_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO383-18_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk198_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk477_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO103-035_casey_bayes_wturn_fixed50.pickle',
#  './pickles/UGC11185NED02_casey_bayes_wturn_fixed50.pickle',
#  './pickles/MCG-02-14-009_casey_bayes_wturn_fixed50.pickle',
#  './pickles/2MASXJ18570768-7828212_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO426-G002_casey_bayes_wturn_fixed50.pickle',
#  './pickles/NGC5548_casey_bayes_wturn_fixed50.pickle',
#  './pickles/IC4709_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ARK347_casey_bayes_wturn_fixed50.pickle',
#  './pickles/NGC6552_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk926_casey_bayes_wturn_fixed50.pickle',
#  './pickles/MCG-03-34-064_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk1310_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO578-G009_casey_bayes_wturn_fixed50.pickle',
#  './pickles/2MASXJ01073963-1139117_casey_bayes_wturn_fixed50.pickle',
#  './pickles/MCG+11-11-032_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk6_casey_bayes_wturn_fixed50.pickle',
#  './pickles/UGC03601_casey_bayes_wturn_fixed50.pickle',
#  './pickles/IRAS03219+4031_casey_bayes_wturn_fixed50.pickle',
#  './pickles/NGC5273_casey_bayes_wturn_fixed50.pickle',
#  './pickles/2MASXJ05580206-3820043_casey_bayes_wturn_fixed50.pickle',
#  './pickles/CGCG319-007_casey_bayes_wturn_fixed50.pickle',
#  './pickles/NGC2110_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO464-G016_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk509_casey_bayes_wturn_fixed50.pickle',
#  './pickles/LCRSB232242.2-384320_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Fairall51_casey_bayes_wturn_fixed50.pickle',
#  './pickles/2MASXJ03342453-1513402_casey_bayes_wturn_fixed50.pickle',
#  './pickles/2MASXJ11454045-1827149_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk1210_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk359_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO195-IG021NED03_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO141-G055_casey_bayes_wturn_fixed50.pickle',
#  './pickles/IGRJ23308+7120_casey_bayes_wturn_fixed50.pickle',
#  './pickles/IIZw083_casey_bayes_wturn_fixed50.pickle',
#  './pickles/2MASXJ13411287-1438407_casey_bayes_wturn_fixed50.pickle',
#  './pickles/MCG+01-57-016_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO509-G038_casey_bayes_wturn_fixed50.pickle',
#  './pickles/CGCG300-062_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Fairall1146_casey_bayes_wturn_fixed50.pickle',
#  './pickles/NGC1194_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Fairall9_casey_bayes_wturn_fixed50.pickle',
#  './pickles/ESO553-G022_casey_bayes_wturn_fixed50.pickle',
#  './pickles/WKK1263_casey_bayes_wturn_fixed50.pickle',
#  './pickles/NGC526A_casey_bayes_wturn_fixed50.pickle',
#  './pickles/UGC12282_casey_bayes_wturn_fixed50.pickle',
#  './pickles/NGC788_casey_bayes_wturn_fixed50.pickle',
#  './pickles/MCG+05-28-032_casey_bayes_wturn_fixed50.pickle',
#  './pickles/LEDA38038_casey_bayes_wturn_fixed50.pickle',
#  './pickles/Mrk975_casey_bayes_wturn_fixed50.pickle']

# %%
# Loop over all of the files and pull out the best-fit parameters for each source
fit_data = pd.DataFrame(columns=['logMdust', 'Tdust', 'beta', 'logNpl', 'alpha', 'wturn'])
for f in pickle_files:
    name = f.split('/')[-1].split('_')[0]
    src_file = open(f, 'rb')
    data = pickle.load(src_file)
    fit_data.loc[name] = data['best_fit_model'].parameters
# Out:
# WARNING: AstropyDeprecationWarning: Config parameter 'default_cosmology' in section [astropy.cosmology.core] is deprecated. Use science state astropy.cosmology.core.default_cosmology instead. [astropy.utils.state]
# WARNING:astropy:AstropyDeprecationWarning: Config parameter 'default_cosmology' in section [astropy.cosmology.core] is deprecated. Use science state astropy.cosmology.core.default_cosmology instead.

# %%
# We can take a look at the DataFrame to make sure everything looks ok.
print(fit_data)
# Out:
#                         logMdust      Tdust      beta    logNpl     alpha  \
# NGC3516                 5.825036  26.668214  2.284783  0.476444  1.530498
# MCG-07-03-007           6.825613  22.447723  2.024422 -0.198075  1.754006
# 2MASXJ20005575-1810274  6.903182  34.030501  1.024689  0.213124  1.188132
# CGCG420-015             6.912467  22.883231  2.120069  0.226812  1.375570
# MCG-03-04-072           7.133984  27.273084  0.518550 -0.567288  1.184237
# Mrk885                  6.962320  24.241161  1.749686 -0.742397  1.474215
# CGCG122-055             6.550544  22.052761  2.392441  0.153998  2.085143
# 2MASXJ12335145-2103448  6.076491  25.402247  2.257592 -0.227816  1.776830
# Mrk279                  6.903825  25.941323  1.874288  0.194830  1.650675
# CGCG493-002             6.423532  26.767190  1.777184 -0.113069  1.367395
# KAZ320                  6.403822  27.052850  2.126264 -0.258174  1.417260
# Mrk653                  7.449447  19.197303  2.000015 -0.496201  1.443262
# IC4329A                 6.478820  24.705729  1.942590  0.774099  1.190088
# NGC235A                 7.124371  21.022754  2.943204  0.505061  2.473129
# ESO506-G027             7.293684  25.795606  0.896504 -0.071927  1.283426
# MCG-01-40-001           7.331962  26.844639  1.183376  0.492221  2.737890
# ESO383-18               6.094283  25.765432  1.846773  0.082761  1.016333
# Mrk198                  6.675684  25.700526  2.256373 -0.422255  1.250206
# Mrk477                  6.828651  26.174550  2.380409  0.398715  2.102654
# ESO103-035              5.640596  29.393591  2.307392  0.647615  1.510023
# UGC11185NED02           7.426541  24.613182  0.804078  0.010045  2.768012
# MCG-02-14-009           7.211012  24.662618  1.132386 -0.269227  1.222821
# 2MASXJ18570768-7828212  6.895931  27.441244  1.493602 -0.162006  1.430942
# ESO426-G002             7.272751  18.424333  1.255786 -0.168076  1.464936
# NGC5548                 6.858345  23.550759  1.849004  0.367046  1.716416
# IC4709                  6.761286  23.611267  1.521293  0.060792  1.854004
# ARK347                  6.682806  24.543437  1.437878 -0.091060  1.554028
# NGC6552                 7.260492  20.750248  2.856970  0.713291  2.462179
# Mrk926                  7.162511  27.969145  1.688140 -0.110034  1.218908
# MCG-03-34-064           6.891804  23.905059  2.543445  1.013576  1.850030
# ...                          ...        ...       ...       ...       ...
# 2MASXJ05580206-3820043  7.167225  21.496473  0.851618  0.039574  0.691356
# CGCG319-007             7.362281  20.180471  2.678015 -0.305396  1.504323
# NGC2110                 6.438509  28.519892  1.861588  0.385165  1.259990
# ESO464-G016             6.792442  32.521748  1.158326 -0.560453  1.842520
# Mrk509                  6.918619  27.833772  2.202348  0.284724  1.302066
# LCRSB232242.2-384320    7.338838  23.211496  2.211825 -0.666282  1.360442
# Fairall51               6.660007  32.263240  0.754934  0.611354  1.705372
# 2MASXJ03342453-1513402  7.086883  26.725190  1.705641 -0.364670  1.614934
# 2MASXJ11454045-1827149  6.569244  31.154996  1.189444 -0.410875  1.168519
# Mrk1210                 6.309112  21.968181  2.478004  0.647269  1.677279
# Mrk359                  6.536808  27.095354  2.040859  0.061474  1.637992
# ESO195-IG021NED03       7.482264  24.706567  1.670590 -0.432545  1.647606
# ESO141-G055             7.447191  22.241786  2.168575 -0.114093  1.020915
# IGRJ23308+7120          7.162833  23.421686  2.106688 -0.783862  1.404420
# IIZw083                 7.188433  20.645278  2.712363  0.457601  1.476908
# 2MASXJ13411287-1438407  7.183457  20.625499  1.396393 -0.332093  1.048576
# MCG+01-57-016           6.862614  26.407329  1.691130  0.163175  1.951878
# ESO509-G038             6.874259  22.435062  2.098884 -0.152691  1.774411
# CGCG300-062             6.941367  22.958051  1.341434 -0.805943  1.581330
# Fairall1146             7.199764  25.388739  1.875712  0.318893  1.568616
# NGC1194                 6.580296  24.896184  0.497944  0.345928  1.600147
# Fairall9                7.150126  23.670679  2.330691  0.036970  0.925696
# ESO553-G022             7.438631  18.974456  2.120596 -1.160408  1.129006
# WKK1263                 6.667489  21.889914  2.928068 -0.074153  1.577892
# NGC526A                 6.447166  23.969896  1.130947 -0.180267  0.992967
# UGC12282                7.361727  24.286403  1.329402 -0.449021  0.877228
# NGC788                  6.942562  19.456850  0.747203  0.260873  1.778603
# MCG+05-28-032           6.842126  26.856380  1.732922 -0.296287  1.564192
# LEDA38038               6.883759  24.983907  2.492313  0.545891  1.743023
# Mrk975                  7.558789  23.884295  2.165672  0.006933  1.300408
#
#                         wturn
# NGC3516                    50
# MCG-07-03-007              50
# 2MASXJ20005575-1810274     50
# CGCG420-015                50
# MCG-03-04-072              50
# Mrk885                     50
# CGCG122-055                50
# 2MASXJ12335145-2103448     50
# Mrk279                     50
# CGCG493-002                50
# KAZ320                     50
# Mrk653                     50
# IC4329A                    50
# NGC235A                    50
# ESO506-G027                50
# MCG-01-40-001              50
# ESO383-18                  50
# Mrk198                     50
# Mrk477                     50
# ESO103-035                 50
# UGC11185NED02              50
# MCG-02-14-009              50
# 2MASXJ18570768-7828212     50
# ESO426-G002                50
# NGC5548                    50
# IC4709                     50
# ARK347                     50
# NGC6552                    50
# Mrk926                     50
# MCG-03-34-064              50
# ...                       ...
# 2MASXJ05580206-3820043     50
# CGCG319-007                50
# NGC2110                    50
# ESO464-G016                50
# Mrk509                     50
# LCRSB232242.2-384320       50
# Fairall51                  50
# 2MASXJ03342453-1513402     50
# 2MASXJ11454045-1827149     50
# Mrk1210                    50
# Mrk359                     50
# ESO195-IG021NED03          50
# ESO141-G055                50
# IGRJ23308+7120             50
# IIZw083                    50
# 2MASXJ13411287-1438407     50
# MCG+01-57-016              50
# ESO509-G038                50
# CGCG300-062                50
# Fairall1146                50
# NGC1194                    50
# Fairall9                   50
# ESO553-G022                50
# WKK1263                    50
# NGC526A                    50
# UGC12282                   50
# NGC788                     50
# MCG+05-28-032              50
# LEDA38038                  50
# Mrk975                     50
#
# [68 rows x 6 columns]

# %%
# Let's plot the pairwise relationship between all of the best fit parameters to see if there are any correlations
# between them.
fig = sns.PairGrid(fit_data, vars=['logMdust', 'Tdust', 'beta', 'logNpl', 'alpha'])
fig.map_upper(plt.scatter)
fig.map_lower(sns.kdeplot)
fig.map_diag(sns.kdeplot, legend=False)

# %% [markdown]
# The only strong correlation seems to be between Tdust and Mdust in the sense where higher Tdust corresponds to lower Mdust. This makes sense since you don't need as much dust to be able to output the same amount of energy when its hotter. The other noticeable thing is that the distributions seems much more broader than for the sources which had no undetected points. There is also an interesting source which has an extremely low amount of dust with logMdust $< 5.0$. Its for NGC5273 which is a known elliptical galaxy, so it makes sense as well. A look at the SED also shows that the fit is good so it seems like a real result.

# %%
ngc5273_fn = './pickles/NGC5273_casey_bayes_wturn_fixed50.pickle'
f = open(ngc5273_fn, 'rb')
ngc5273_data = pickle.load(f)

# %%
ngc5273_data.keys()
# Out:
# ['name', 'flux_err', 'flux', 'best_fit_model', 'filters', 'waves']

# %%
det = np.isfinite(ngc5273_data['flux'])
plt.loglog(ngc5273_data['waves'][det], ngc5273_data['flux'][det], 'ko')
w = np.arange(1, 1000)
plt.loglog(w, ngc5273_data['best_fit_model'](w))
plt.xlabel('Wavelength [micron]')
plt.ylabel('Flux Density [Jy]')
plt.ylim(0.01, 1)
plt.xlim(10, 1000)
plt.title('NGC 5273')

# %%
fit_data.describe(percentiles=[0.025, 0.16, 0.50, 0.84, 0.975])
# Out:
#         logMdust      Tdust       beta     logNpl      alpha  wturn
# count  68.000000  68.000000  68.000000  68.000000  68.000000     68
# mean    6.869644  24.922874   1.775481  -0.049616   1.546405     50
# std     0.481606   3.620166   0.619541   0.463412   0.438199      0
# min     4.903499  18.424333   0.497944  -1.160408   0.691356     50
# 2.5%    5.765093  19.124878   0.633997  -0.946152   0.909944     50
# 16%     6.465064  21.779750   1.131983  -0.482595   1.159796     50
# 50%     6.903503  24.637900   1.867938  -0.082607   1.520260     50
# 84%     7.336369  27.551152   2.344612   0.415203   1.851143     50
# 97.5%   7.466250  33.012093   2.880077   0.733053   2.747679     50
# max     7.558789  37.578480   2.943204   1.013576   2.885186     50

# %% [markdown]
# Based on the statistics from this fitting run, it looks like not much has changed from the first run where all of the sources were detected at all wavelengths. The median $T_{dust}$ is 25 K, $\beta$ is 1.87, $\alpha$ is 1.5 compared to 25 K, 1.8, and 1.6 from before. The difference is definitely well within the uncertainties of those values. Also $M_{dust}$ is still right around $10^7$ solar masses. This only confirms that for the next run we can be confident in fixing $\beta=1.8$.

# %% [markdown]
# I want to make a list of sources that I think are probably going to warrant a re-fit using different fixed parameters. We most likely need to adjust the turnover wavelength or possibly let it be free and fix dust temperature.
# * ESO103-035
# * Mrk1210
# * NGC 788
